# %%
#A1
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})

# %%
#B1
#

# %%
#B2
import pandas as pd

df = pd.read_csv('https://gist.githubusercontent.com/lintonylin/4f9ba13dc37b7510ea392d95c494f891/raw/1092dba2c54ed10d03f2999d8ad7878757b39a8f/Space_Cleaned.csv')
df.head()
# Out:
#    id Company Name                                           Location  \
# 0   0       SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1   1         CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2   2       SpaceX                      Pad A, Boca Chica, Texas, USA
# 3   3    Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4   4          ULA           SLC-41, Cape Canaveral AFS, Florida, USA
#
#                         Datum                                        Detail  \
# 0  Fri Aug 07, 2020 05:12 UTC  Falcon 9 Block 5 | Starlink V1 L9 & BlackSky
# 1  Thu Aug 06, 2020 04:01 UTC           Long March 2D | Gaofen-9 04 & Q-SAT
# 2  Tue Aug 04, 2020 23:57 UTC            Starship Prototype | 150 Meter Hop
# 3  Thu Jul 30, 2020 21:25 UTC  Proton-M/Briz-M | Ekspress-80 & Ekspress-103
# 4  Thu Jul 30, 2020 11:50 UTC                    Atlas V 541 | Perseverance
#
#   Status Rocket  Rocket Status Mission                   Country  Year
# ...

# %%
#B3.1&2
#The column that is interesting is Status Mission where it basically shows the conclusion of the test or experiment. Also the countries column which show where the success occured.
df.describe().T
import pandas_profiling as pdp
# Out:
#        count         mean          std     min      25%     50%      75%  \
# id    4284.0  2173.017974  1248.313326     0.0  1102.75  2181.5  3252.25
# Year  4284.0  1987.215920    18.064993  1957.0  1972.00  1984.0  2002.00
#
#          max
# id    4323.0
# Year  2020.0

# %%
#B5.1&2
import pandas_profiling as pdp
df = df.rename(columns={" Rocket": " Mission Cost"})
df = df.dropna()
df.head()
# Out:
# The last launch in the dataset happened: Wed Sep 30, 2015 20:30 UTC
# The first launch in the dataset happened: Fri Apr 04, 1997 16:47 UTC
#      Mission Cost  Company Name                   Country  \
# 24             12  Virgin Orbit  United States of America
# 425          41.8        VKS RF        Russian Federation
# 316          41.8        VKS RF        Russian Federation
# 518          41.8        VKS RF        Russian Federation
# 336          48.5        VKS RF        Russian Federation
#
#                           Datum  \
# 24   Mon May 25, 2020 19:50 UTC
# 425  Fri Nov 22, 2013 12:02 UTC
# 316  Sat Jun 04, 2016 14:00 UTC
# 518  Wed Sep 08, 2010 03:30 UTC
# 336  Sun Feb 07, 2016 00:21 UTC
#
#                                                 Detail  \
# 24                           LauncherOne | Demo Flight
# 425                              Rokot/Briz KM | SWARM
# 316                        Rokot/Briz KM | Cosmos 2517
# ...

# %%
#B5.3&4
rslt_df = df.sort_index(axis = 1)
rslt_df.head()
# Out:
#      Mission Cost  Company Name                   Country  \
# 24             12  Virgin Orbit  United States of America
# 425          41.8        VKS RF        Russian Federation
# 316          41.8        VKS RF        Russian Federation
# 518          41.8        VKS RF        Russian Federation
# 336          48.5        VKS RF        Russian Federation
#
#                           Datum  \
# 24   Mon May 25, 2020 19:50 UTC
# 425  Fri Nov 22, 2013 12:02 UTC
# 316  Sat Jun 04, 2016 14:00 UTC
# 518  Wed Sep 08, 2010 03:30 UTC
# 336  Sun Feb 07, 2016 00:21 UTC
#
#                                                 Detail  \
# 24                           LauncherOne | Demo Flight
# 425                              Rokot/Briz KM | SWARM
# 316                        Rokot/Briz KM | Cosmos 2517
# 518  Rokot/Briz KM | Cosmos 2467, 2468 and Goniets-...
# 336               Soyuz 2.1b/Fregat | GLONASS-M No.50S
#
#                                               Location Status Mission  \
# ...

# %%
#B5.7
column = df["Datum"]
max_value = column.max()
print("The last launch in the dataset happened:",max_value)
column = df["Datum"]
min_value = column.min()
print("The first launch in the dataset happened:",min_value)
# Out:
# The last launch in the dataset happened: Wed Sep 30, 2015 20:30 UTC
# The first launch in the dataset happened: Fri Apr 04, 1997 16:47 UTC

# %%
#B6.1
#1. Do certain countries have more resources and connections that leads to better results and higher chances of success?
#2. How has technology developed over the years to effect the chances of success over the years?

# %%
#B7.1
import seaborn as sns
sns.set_theme(style="darkgrid")
ax = sns.countplot(y="Status Mission", data=rslt_df)

# %%
#B7.2
sns.set_theme(style="darkgrid")
ax = sns.countplot(y="Country", order = df['Country'].value_counts().index,data=df)

# %%
#B7.3
sns.set_theme(style="darkgrid")
ax = sns.countplot(y="Company Name",hue="Status Mission", order = df['Company Name'].value_counts().index,data=df)

# %%
#B7.4
sns.set_theme(style="darkgrid")
ax = sns.displot(x="Year",hue="Status Mission",data=df)

# %%
#C1
df = (
        pd.read_csv('https://gist.githubusercontent.com/lintonylin/4f9ba13dc37b7510ea392d95c494f891/raw/1092dba2c54ed10d03f2999d8ad7878757b39a8f/Space_Cleaned.csv')
        .rename(columns={" Rocket": " Mission Cost"})
        .dropna()
        .sort_index(axis = 1)
        .reset_index(drop=True)
        .sort_values("Company Name", ascending=False)
        )
df
# Out:
#      Mission Cost  Company Name                   Country  \
# 24             12  Virgin Orbit  United States of America
# 425          41.8        VKS RF        Russian Federation
# 316          41.8        VKS RF        Russian Federation
# 518          41.8        VKS RF        Russian Federation
# 336          48.5        VKS RF        Russian Federation
# ..            ...           ...                       ...
# 351           200   Arianespace                    France
# 150           200   Arianespace                    France
# 509           200   Arianespace                    France
# 294           200   Arianespace                    France
# 98            200   Arianespace                    France
#
#                           Datum  \
# 24   Mon May 25, 2020 19:50 UTC
# 425  Fri Nov 22, 2013 12:02 UTC
# 316  Sat Jun 04, 2016 14:00 UTC
# 518  Wed Sep 08, 2010 03:30 UTC
# 336  Sun Feb 07, 2016 00:21 UTC
# ..                          ...
# 351  Wed Sep 30, 2015 20:30 UTC
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('https://gist.githubusercontent.com/lintonylin/4f9ba13dc37b7510ea392d95c494f891/raw/1092dba2c54ed10d03f2999d8ad7878757b39a8f/Space_Cleaned.csv')
df.head()
# Out:
#    id Company Name                                           Location  \
# 0   0       SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1   1         CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2   2       SpaceX                      Pad A, Boca Chica, Texas, USA
# 3   3    Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4   4          ULA           SLC-41, Cape Canaveral AFS, Florida, USA
#
#                         Datum                                        Detail  \
# 0  Fri Aug 07, 2020 05:12 UTC  Falcon 9 Block 5 | Starlink V1 L9 & BlackSky
# 1  Thu Aug 06, 2020 04:01 UTC           Long March 2D | Gaofen-9 04 & Q-SAT
# 2  Tue Aug 04, 2020 23:57 UTC            Starship Prototype | 150 Meter Hop
# 3  Thu Jul 30, 2020 21:25 UTC  Proton-M/Briz-M | Ekspress-80 & Ekspress-103
# 4  Thu Jul 30, 2020 11:50 UTC                    Atlas V 541 | Perseverance
#
#   Status Rocket  Rocket Status Mission                   Country  Year
# ...
